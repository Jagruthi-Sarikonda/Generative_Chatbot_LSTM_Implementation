# %% [markdown]
# ## Importing the packages

# %%
import numpy as np
import tensorflow as tf
import pickle
from tensorflow.keras import layers , activations , models , preprocessing

# %% [markdown]
# ## Preprocessing the data

# %%
# !wget https://github.com/Jagruthi-Sarikonda/Generative_Chatbot_LSTM_Implementation/blob/main/chatbot_nlp.zip?raw=true -O chatbot_nlp.zip
# !unzip chatbot_nlp.zip
# Out:
# --2023-11-23 10:42:21--  https://github.com/Jagruthi-Sarikonda/Generative_Chatbot_LSTM_Implementation/blob/main/chatbot_nlp.zip?raw=true
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/Jagruthi-Sarikonda/Generative_Chatbot_LSTM_Implementation/raw/main/chatbot_nlp.zip [following]
# --2023-11-23 10:42:21--  https://github.com/Jagruthi-Sarikonda/Generative_Chatbot_LSTM_Implementation/raw/main/chatbot_nlp.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Jagruthi-Sarikonda/Generative_Chatbot_LSTM_Implementation/main/chatbot_nlp.zip [following]
# --2023-11-23 10:42:21--  https://raw.githubusercontent.com/Jagruthi-Sarikonda/Generative_Chatbot_LSTM_Implementation/main/chatbot_nlp.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24292 (24K) [application/zip]
# Saving to: ‘chatbot_nlp.zip’
#
# chatbot_nlp.zip     100%[===================>]  23.72K  --.-KB/s    in 0s
#
# 2023-11-23 10:42:21 (75.1 MB/s) - ‘chatbot_nlp.zip’ saved [24292/24292]
#
# Archive:  chatbot_nlp.zip
#    creating: chatbot_nlp/
#    creating: chatbot_nlp/data/
#   inflating: chatbot_nlp/data/ai.yml
#   inflating: chatbot_nlp/data/botprofile.yml
#   inflating: chatbot_nlp/data/computers.yml
#   inflating: chatbot_nlp/data/emotion.yml
#   inflating: chatbot_nlp/data/food.yml
#   inflating: chatbot_nlp/data/gossip.yml
#   inflating: chatbot_nlp/data/greetings.yml
#   inflating: chatbot_nlp/data/health.yml
#   inflating: chatbot_nlp/data/history.yml
#   inflating: chatbot_nlp/data/humor.yml
#   inflating: chatbot_nlp/data/literature.yml
#   inflating: chatbot_nlp/data/money.yml
#   inflating: chatbot_nlp/data/movies.yml
#   inflating: chatbot_nlp/data/politics.yml
#   inflating: chatbot_nlp/data/psychology.yml
#   inflating: chatbot_nlp/data/science.yml
#   inflating: chatbot_nlp/data/sports.yml
#   inflating: chatbot_nlp/data/trivia.yml

# %% [markdown]
# ### Reading the data from the files
#
# We analyze every .yaml file, merging sentences as needed. Eliminate undesired data types generated during data parsing. Add <START> and <END> to all responses. Establish a Tokenizer and integrate the entire vocabulary (questions + answers) into it.

# %%
from tensorflow.keras import preprocessing , utils
import os
import yaml

dir_path = 'chatbot_nlp/data'
files_list = os.listdir(dir_path + os.sep)

questions = list()
answers = list()

for filepath in files_list:
    stream = open( dir_path + os.sep + filepath , 'rb')
    docs = yaml.safe_load(stream)
    conversations = docs['conversations']
    for con in conversations:
        if len( con ) > 2 :
            questions.append(con[0])
            replies = con[ 1 : ]
            ans = ''
            for rep in replies:
                ans += ' ' + rep
            answers.append( ans )
        elif len( con )> 1:
            questions.append(con[0])
            answers.append(con[1])

answers_with_tags = list()
for i in range( len( answers ) ):
    if type( answers[i] ) == str:
        answers_with_tags.append( answers[i] )
    else:
        questions.pop( i )

answers = list()
for i in range( len( answers_with_tags ) ) :
    answers.append( '<START> ' + answers_with_tags[i] + ' <END>' )

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts( questions + answers )
VOCAB_SIZE = len( tokenizer.word_index )+1
print( 'VOCAB SIZE : {}'.format( VOCAB_SIZE ))
# Out:
# VOCAB SIZE : 1894

# %% [markdown]
# ### Preparing data for Seq2Seq model

# %%
# encoder_input_data
tokenized_questions = tokenizer.texts_to_sequences( questions )
maxlen_questions = max( [ len(x) for x in tokenized_questions ] )
padded_questions = preprocessing.sequence.pad_sequences( tokenized_questions , maxlen=maxlen_questions , padding='post' )
encoder_input_data = np.array( padded_questions )
print( encoder_input_data.shape , maxlen_questions )

# decoder_input_data
tokenized_answers = tokenizer.texts_to_sequences( answers )
maxlen_answers = max( [ len(x) for x in tokenized_answers ] )
padded_answers = preprocessing.sequence.pad_sequences( tokenized_answers , maxlen=maxlen_answers , padding='post' )
decoder_input_data = np.array( padded_answers )
print( decoder_input_data.shape , maxlen_answers )

# decoder_output_data
tokenized_answers = tokenizer.texts_to_sequences( answers )
for i in range(len(tokenized_answers)) :
    tokenized_answers[i] = tokenized_answers[i][1:]
padded_answers = preprocessing.sequence.pad_sequences( tokenized_answers , maxlen=maxlen_answers , padding='post' )
onehot_answers = utils.to_categorical( padded_answers , VOCAB_SIZE )
decoder_output_data = np.array( onehot_answers )
print( decoder_output_data.shape )
# Out:
# (564, 22) 22
# (564, 74) 74
# (564, 74, 1894)

# %% [markdown]
# ## Defining the Encoder-Decoder model

# %%
encoder_inputs = tf.keras.layers.Input(shape=( maxlen_questions , ))
encoder_embedding = tf.keras.layers.Embedding( VOCAB_SIZE, 200 , mask_zero=True ) (encoder_inputs)
encoder_outputs , state_h , state_c = tf.keras.layers.LSTM( 200 , return_state=True )( encoder_embedding )
encoder_states = [ state_h , state_c ]

decoder_inputs = tf.keras.layers.Input(shape=( maxlen_answers ,  ))
decoder_embedding = tf.keras.layers.Embedding( VOCAB_SIZE, 200 , mask_zero=True) (decoder_inputs) # 200-dimensional GloVe embeddings
decoder_lstm = tf.keras.layers.LSTM( 200 , return_state=True , return_sequences=True )
decoder_outputs , _ , _ = decoder_lstm ( decoder_embedding , initial_state=encoder_states )
decoder_dense = tf.keras.layers.Dense( VOCAB_SIZE , activation=tf.keras.activations.softmax )
output = decoder_dense ( decoder_outputs )

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], output )
model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='categorical_crossentropy')

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 22)]                 0         []
#
#  input_2 (InputLayer)        [(None, 74)]                 0         []
#
#  embedding (Embedding)       (None, 22, 200)              378800    ['input_1[0][0]']
#
#  embedding_1 (Embedding)     (None, 74, 200)              378800    ['input_2[0][0]']
#
#  lstm (LSTM)                 [(None, 200),                320800    ['embedding[0][0]']
#                               (None, 200),
#                               (None, 200)]
#
#  lstm_1 (LSTM)               [(None, 74, 200),            320800    ['embedding_1[0][0]',
#                               (None, 200),                           'lstm[0][1]',
#                               (None, 200)]                           'lstm[0][2]']
#
#  dense (Dense)               (None, 74, 1894)             380694    ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 1779894 (6.79 MB)
# Trainable params: 1779894 (6.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## 4) Training the model
# We train the model for a number of epochs with `RMSprop` optimizer and `categorical_crossentropy` loss function.

# %%
model.fit([encoder_input_data , decoder_input_data], decoder_output_data, batch_size=50, epochs=150 )
model.save( 'model.h5' )
# Out:
# Epoch 1/150
# 12/12 [==============================] - 17s 185ms/step - loss: 7.5244
# Epoch 2/150
# 12/12 [==============================] - 3s 224ms/step - loss: 6.7254
# Epoch 3/150
# 12/12 [==============================] - 3s 224ms/step - loss: 5.9840
# Epoch 4/150
# 12/12 [==============================] - 2s 154ms/step - loss: 5.8289
# Epoch 5/150
# 12/12 [==============================] - 1s 123ms/step - loss: 5.7791
# Epoch 6/150
# 12/12 [==============================] - 1s 95ms/step - loss: 5.7500
# Epoch 7/150
# 12/12 [==============================] - 2s 137ms/step - loss: 5.7284
# Epoch 8/150
# 12/12 [==============================] - 1s 78ms/step - loss: 5.7035
# Epoch 9/150
# 12/12 [==============================] - 1s 105ms/step - loss: 5.6729
# Epoch 10/150
# 12/12 [==============================] - 1s 95ms/step - loss: 5.6493
# Epoch 11/150
# 12/12 [==============================] - 2s 162ms/step - loss: 5.6224
# Epoch 12/150
# 12/12 [==============================] - 1s 108ms/step - loss: 5.5796
# Epoch 13/150
# 12/12 [==============================] - 1s 88ms/step - loss: 5.5391
# Epoch 14/150
# 12/12 [==============================] - 1s 74ms/step - loss: 5.4952
# Epoch 15/150
# 12/12 [==============================] - 1s 67ms/step - loss: 5.4532
# Epoch 16/150
# 12/12 [==============================] - 1s 104ms/step - loss: 5.4067
# Epoch 17/150
# 12/12 [==============================] - 1s 82ms/step - loss: 5.3753
# Epoch 18/150
# 12/12 [==============================] - 1s 45ms/step - loss: 5.3593
# Epoch 19/150
# 12/12 [==============================] - 1s 71ms/step - loss: 5.3344
# Epoch 20/150
# 12/12 [==============================] - 1s 60ms/step - loss: 5.3185
# Epoch 21/150
# 12/12 [==============================] - 1s 43ms/step - loss: 5.2969
# Epoch 22/150
# 12/12 [==============================] - 1s 68ms/step - loss: 5.2833
# Epoch 23/150
# 12/12 [==============================] - 1s 60ms/step - loss: 5.2630
# Epoch 24/150
# 12/12 [==============================] - 1s 52ms/step - loss: 5.2390
# Epoch 25/150
# 12/12 [==============================] - 1s 49ms/step - loss: 5.2215
# Epoch 26/150
# 12/12 [==============================] - 1s 80ms/step - loss: 5.2016
# Epoch 27/150
# 12/12 [==============================] - 1s 91ms/step - loss: 5.1822
# Epoch 28/150
# 12/12 [==============================] - 1s 45ms/step - loss: 5.1638
# Epoch 29/150
# 12/12 [==============================] - 1s 45ms/step - loss: 5.1445
# Epoch 30/150
# 12/12 [==============================] - 1s 67ms/step - loss: 5.1174
# Epoch 31/150
# 12/12 [==============================] - 1s 53ms/step - loss: 5.0977
# Epoch 140/150
# 12/12 [==============================] - 1s 47ms/step - loss: 3.1095
# Epoch 141/150
# 12/12 [==============================] - 0s 39ms/step - loss: 3.0947
# Epoch 142/150
# 12/12 [==============================] - 1s 33ms/step - loss: 3.0770
# Epoch 143/150
# 12/12 [==============================] - 0s 32ms/step - loss: 3.0598
# Epoch 144/150
# 12/12 [==============================] - 0s 33ms/step - loss: 3.0407
# Epoch 145/150
# 12/12 [==============================] - 0s 33ms/step - loss: 3.0223
# Epoch 146/150
# 12/12 [==============================] - 1s 43ms/step - loss: 3.0119
# Epoch 147/150
# 12/12 [==============================] - 0s 38ms/step - loss: 2.9914
# Epoch 148/150
# 12/12 [==============================] - 0s 34ms/step - loss: 2.9867
# Epoch 149/150
# 12/12 [==============================] - 0s 33ms/step - loss: 2.9737
# Epoch 150/150
# 12/12 [==============================] - 0s 31ms/step - loss: 2.9513
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and validation sets
encoder_input_train, encoder_input_val, decoder_input_train, decoder_input_val, decoder_output_train, decoder_output_val = train_test_split(
    encoder_input_data, decoder_input_data, decoder_output_data, test_size=0.2, random_state=42
)

# Train the model with validation data
model.fit(
    [encoder_input_train, decoder_input_train],
    decoder_output_train,
    validation_data=([encoder_input_val, decoder_input_val], decoder_output_val),
    batch_size=50,
    epochs=150
)

# Save the trained model
model.save('model.h5')
# Out:
# Epoch 1/150
# 10/10 [==============================] - 5s 503ms/step - loss: 2.9341 - val_loss: 2.9856
# Epoch 2/150
# 10/10 [==============================] - 0s 50ms/step - loss: 2.9166 - val_loss: 3.0294
# Epoch 3/150
# 10/10 [==============================] - 1s 75ms/step - loss: 2.8943 - val_loss: 3.0781
# Epoch 4/150
# 10/10 [==============================] - 1s 73ms/step - loss: 2.8647 - val_loss: 3.1169
# Epoch 5/150
# 10/10 [==============================] - 1s 55ms/step - loss: 2.8634 - val_loss: 3.1366
# Epoch 6/150
# 10/10 [==============================] - 1s 57ms/step - loss: 2.8394 - val_loss: 3.1695
# Epoch 7/150
# 10/10 [==============================] - 1s 58ms/step - loss: 2.8349 - val_loss: 3.2575
# Epoch 8/150
# 10/10 [==============================] - 1s 55ms/step - loss: 2.8193 - val_loss: 3.2296
# Epoch 9/150
# 10/10 [==============================] - 1s 66ms/step - loss: 2.7934 - val_loss: 3.2992
# Epoch 10/150
# 10/10 [==============================] - 1s 53ms/step - loss: 2.7880 - val_loss: 3.2753
# Epoch 11/150
# 10/10 [==============================] - 1s 54ms/step - loss: 2.7433 - val_loss: 3.2846
# Epoch 12/150
# 10/10 [==============================] - 1s 57ms/step - loss: 2.7537 - val_loss: 3.3277
# Epoch 13/150
# 10/10 [==============================] - 0s 40ms/step - loss: 2.7437 - val_loss: 3.3390
# Epoch 14/150
# 10/10 [==============================] - 1s 52ms/step - loss: 2.7289 - val_loss: 3.3375
# Epoch 15/150
# 10/10 [==============================] - 1s 70ms/step - loss: 2.7019 - val_loss: 3.3755
# Epoch 72/150
# 10/10 [==============================] - 1s 55ms/step - loss: 2.0472 - val_loss: 3.8398
# Epoch 73/150
# 10/10 [==============================] - 1s 54ms/step - loss: 2.0189 - val_loss: 3.8604
# Epoch 74/150
# 10/10 [==============================] - 1s 61ms/step - loss: 2.0046 - val_loss: 3.8549
# Epoch 75/150
# 10/10 [==============================] - 1s 59ms/step - loss: 2.0019 - val_loss: 3.8480
# Epoch 76/150
# 10/10 [==============================] - 1s 60ms/step - loss: 1.9842 - val_loss: 3.8449
# Epoch 77/150
# 10/10 [==============================] - 0s 49ms/step - loss: 1.9802 - val_loss: 3.8586
# Epoch 78/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.9682 - val_loss: 3.8739
# Epoch 79/150
# 10/10 [==============================] - 1s 52ms/step - loss: 1.9677 - val_loss: 3.8575
# Epoch 80/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.9413 - val_loss: 3.8585
# Epoch 81/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.9379 - val_loss: 3.9134
# Epoch 82/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.9279 - val_loss: 3.8969
# Epoch 83/150
# 10/10 [==============================] - 0s 39ms/step - loss: 1.9242 - val_loss: 3.9059
# Epoch 84/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.9124 - val_loss: 3.8959
# Epoch 85/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.8978 - val_loss: 3.9022
# Epoch 86/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.8883 - val_loss: 3.9138
# Epoch 87/150
# 10/10 [==============================] - 0s 45ms/step - loss: 1.8788 - val_loss: 3.9020
# Epoch 88/150
# 10/10 [==============================] - 0s 43ms/step - loss: 1.8713 - val_loss: 3.9080
# Epoch 89/150
# 10/10 [==============================] - 0s 43ms/step - loss: 1.8635 - val_loss: 3.9054
# Epoch 90/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.8438 - val_loss: 3.9206
# Epoch 91/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.8337 - val_loss: 3.9334
# Epoch 92/150
# 10/10 [==============================] - 1s 53ms/step - loss: 1.8205 - val_loss: 3.9366
# Epoch 93/150
# 10/10 [==============================] - 0s 39ms/step - loss: 1.8162 - val_loss: 3.9425
# Epoch 94/150
# 10/10 [==============================] - 1s 54ms/step - loss: 1.8082 - val_loss: 3.9343
# Epoch 95/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.8001 - val_loss: 3.9583
# Epoch 96/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.7785 - val_loss: 3.9558
# Epoch 97/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.7856 - val_loss: 4.0265
# Epoch 98/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.7826 - val_loss: 3.9878
# Epoch 99/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.7609 - val_loss: 3.9908
# Epoch 100/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.7532 - val_loss: 4.0450
# Epoch 101/150
# 10/10 [==============================] - 1s 65ms/step - loss: 1.7590 - val_loss: 3.9732
# Epoch 102/150
# 10/10 [==============================] - 1s 68ms/step - loss: 1.7217 - val_loss: 3.9939
# Epoch 103/150
# 10/10 [==============================] - 1s 59ms/step - loss: 1.7130 - val_loss: 4.0095
# Epoch 104/150
# 10/10 [==============================] - 1s 59ms/step - loss: 1.7166 - val_loss: 3.9934
# Epoch 105/150
# 10/10 [==============================] - 1s 76ms/step - loss: 1.7121 - val_loss: 4.0021
# Epoch 106/150
# 10/10 [==============================] - 1s 57ms/step - loss: 1.6957 - val_loss: 4.0220
# Epoch 107/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.6867 - val_loss: 4.0127
# Epoch 108/150
# 10/10 [==============================] - 1s 54ms/step - loss: 1.6748 - val_loss: 4.0106
# Epoch 109/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.6740 - val_loss: 4.0120
# Epoch 110/150
# 10/10 [==============================] - 0s 48ms/step - loss: 1.6502 - val_loss: 4.0242
# Epoch 111/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.6507 - val_loss: 4.0368
# Epoch 112/150
# 10/10 [==============================] - 0s 39ms/step - loss: 1.6525 - val_loss: 4.0379
# Epoch 113/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.6386 - val_loss: 4.0423
# Epoch 114/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.6153 - val_loss: 4.0435
# Epoch 115/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.6165 - val_loss: 4.0538
# Epoch 116/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.6087 - val_loss: 4.0540
# Epoch 117/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.6043 - val_loss: 4.0609
# Epoch 118/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.5872 - val_loss: 4.0757
# Epoch 119/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.5785 - val_loss: 4.0739
# Epoch 120/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.5688 - val_loss: 4.1099
# Epoch 121/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.5823 - val_loss: 4.0872
# Epoch 122/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.5588 - val_loss: 4.0847
# Epoch 123/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.5510 - val_loss: 4.0876
# Epoch 124/150
# 10/10 [==============================] - 0s 47ms/step - loss: 1.5406 - val_loss: 4.0869
# Epoch 125/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.5322 - val_loss: 4.1588
# Epoch 126/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.5249 - val_loss: 4.1047
# Epoch 127/150
# 10/10 [==============================] - 0s 39ms/step - loss: 1.5161 - val_loss: 4.1024
# Epoch 128/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.5064 - val_loss: 4.1485
# Epoch 129/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.5023 - val_loss: 4.1169
# Epoch 130/150
# 10/10 [==============================] - 0s 43ms/step - loss: 1.4834 - val_loss: 4.1527
# Epoch 131/150
# 10/10 [==============================] - 1s 58ms/step - loss: 1.4934 - val_loss: 4.1238
# Epoch 132/150
# 10/10 [==============================] - 1s 58ms/step - loss: 1.4757 - val_loss: 4.1661
# Epoch 133/150
# 10/10 [==============================] - 1s 66ms/step - loss: 1.4768 - val_loss: 4.1260
# Epoch 134/150
# 10/10 [==============================] - 1s 60ms/step - loss: 1.4492 - val_loss: 4.1295
# Epoch 135/150
# 10/10 [==============================] - 1s 58ms/step - loss: 1.4540 - val_loss: 4.1480
# Epoch 136/150
# 10/10 [==============================] - 1s 61ms/step - loss: 1.4451 - val_loss: 4.1592
# Epoch 137/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.4329 - val_loss: 4.1499
# Epoch 138/150
# 10/10 [==============================] - 0s 45ms/step - loss: 1.4291 - val_loss: 4.1740
# Epoch 139/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.4248 - val_loss: 4.1449
# Epoch 140/150
# 10/10 [==============================] - 0s 43ms/step - loss: 1.3982 - val_loss: 4.2132
# Epoch 141/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.4173 - val_loss: 4.1680
# Epoch 142/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.3943 - val_loss: 4.1892
# Epoch 143/150
# 10/10 [==============================] - 0s 41ms/step - loss: 1.3918 - val_loss: 4.1674
# Epoch 144/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.3837 - val_loss: 4.2021
# Epoch 145/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.3788 - val_loss: 4.1791
# Epoch 146/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.3603 - val_loss: 4.2079
# Epoch 147/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.3613 - val_loss: 4.2410
# Epoch 148/150
# 10/10 [==============================] - 0s 42ms/step - loss: 1.3524 - val_loss: 4.1956
# Epoch 149/150
# 10/10 [==============================] - 0s 40ms/step - loss: 1.3335 - val_loss: 4.2107
# Epoch 150/150
# 10/10 [==============================] - 0s 49ms/step - loss: 1.3315 - val_loss: 4.2133
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## 5) Defining inference models
# We create inference models which help in predicting answers.
#
# **Encoder inference model** : Takes the question as input and outputs LSTM states ( `h` and `c` ).
#
# **Decoder inference model** : Takes in 2 inputs, one are the LSTM states ( Output of encoder model ), second are the answer input seqeunces ( ones not having the `<start>` tag ). It will output the answers for the question which we fed to the encoder model and its state values.

# %%
def make_inference_models():

    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)

    decoder_state_input_h = tf.keras.layers.Input(shape=( 200 ,))
    decoder_state_input_c = tf.keras.layers.Input(shape=( 200 ,))

    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

    decoder_outputs, state_h, state_c = decoder_lstm(
        decoder_embedding , initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = tf.keras.models.Model(
        [decoder_inputs] + decoder_states_inputs,
        [decoder_outputs] + decoder_states)

    return encoder_model , decoder_model

# %% [markdown]
# ## Talking with our Chatbot

# %%
def str_to_tokens( sentence : str ):
    words = sentence.lower().split()
    tokens_list = list()
    for word in words:
        tokens_list.append( tokenizer.word_index[ word ] )
    return preprocessing.sequence.pad_sequences( [tokens_list] , maxlen=maxlen_questions , padding='post')

# %% [markdown]
# 1. Initially, we input a question to enc_model to predict the state values.
# 2. The obtained state values are then configured in the decoder's LSTM.
# 3. Next, we create a sequence that starts with the `<start>` element. This sequence is fed into the dec_model.
# 4. Subsequently, we replace the `<start>` element with the element predicted by the dec_model and update the state values.
# 5. These steps are repeated iteratively until we reach the `<end>` tag or reach the maximum answer length.

# %%
enc_model, dec_model = make_inference_models()

for _ in range(10):
    states_values = enc_model.predict(str_to_tokens(input('Enter question: ')))

    # Initialize target sequence with the '<start>' token
    empty_target_seq = np.zeros((1, 1))
    empty_target_seq[0, 0] = tokenizer.word_index['start']

    stop_condition = False
    decoded_translation = ''

    while not stop_condition:
        dec_outputs, h, c = dec_model.predict([empty_target_seq] + states_values)

        # Get the index of the predicted word
        sampled_word_index = np.argmax(dec_outputs[0, -1, :])

        # Convert the index to the corresponding word
        sampled_word = None
        for word, index in tokenizer.word_index.items():
            if sampled_word_index == index:
                decoded_translation += ' {}'.format(word)
                sampled_word = word

        # Check for termination conditions
        if sampled_word == 'end' or len(decoded_translation.split()) > maxlen_answers:
            stop_condition = True

        # Append the predicted word index to the target sequence
        empty_target_seq = np.zeros((1, 1))
        empty_target_seq[0, 0] = sampled_word_index

        # Update the states values
        states_values = [h, c]

    print(decoded_translation)
